# %%
import googlemaps
from datetime import datetime
import pandas as pd
import os
from dotenv import load_dotenv

# Carga las variables del archivo .env
load_dotenv()

# Obtiene la clave de la variable de entorno
api_key = os.getenv('GOOGLE_MAPS_API_KEY')
gmaps = googlemaps.Client(key=api_key)

# Tu ubicación actual (u origen)
origen = "Terminal de omnibus Mariano Moreno, Rosario, Argentina"

# Lista de 5 lugares (pueden ser nombres o direcciones)
lugares = ["Bar El Cairo", "Alto Rosario Shopping", "Museo Castagnino", "VIP Rosario", "Ruffo coffee co."]

nodos = [origen] + lugares

# Obtener coordenadas y horarios (Places & Geocoding)
datos_lugares = []
for p in nodos:
    res = gmaps.geocode(p)
    if res:
        place_id = res[0]['place_id']
        # Traemos detalles adicionales como el horario
        detalles = gmaps.place(place_id=place_id, fields=['name', 'opening_hours', 'geometry'])
        
        nombre = detalles['result']['name']
        coord = detalles['result']['geometry']['location']
        # Obtenemos el horario de hoy o un mensaje si no tiene
        horario = detalles['result'].get('opening_hours', {}).get('weekday_text', "No disponible")
        
        datos_lugares.append({
            'nombre': nombre,
            'coords': coord,
            'horarios': horario
        })

# Cálculo de la Matriz "Todos contra Todos"
coords_solo = [d['coords'] for d in datos_lugares]
nombres_solo = [d['nombre'] for d in datos_lugares]

matriz_res = gmaps.distance_matrix(
    origins=coords_solo,
    destinations=coords_solo,
    mode="driving", 
    departure_time=datetime.now()
)

# %%
#guardar la matriz_res
#df = pd.DataFrame(matriz_res['rows'])
#df.to_csv('matriz_res.csv', index=False)

import pickle
with open('datos_lugares.pkl', 'wb') as f:
    pickle.dump(datos_lugares, f)

# %%
with open('datos_lugares.pkl', 'rb') as f:
    datos_lugares = pickle.load(f)

# %%
matriz_res
# Out:
# {'destination_addresses': ['Cafferata 707, S2002MBM Rosario, Santa Fe, Argentina',
#   'Sarmiento 698, S2000CMH Rosario, Santa Fe, Argentina',
#   'Junín 501, S2000 Rosario, Santa Fe, Argentina',
#   'Av. Pellegrini 2202, S2000QDN Rosario, Santa Fe, Argentina',
#   'Rioja 411, S2000AYA Rosario, Santa Fe, Argentina',
#   'Jujuy 2581, S2000 Rosario, Santa Fe, Argentina'],
#  'origin_addresses': ['Cafferata 707, S2002MBM Rosario, Santa Fe, Argentina',
#   'Sarmiento 698, S2000CMH Rosario, Santa Fe, Argentina',
#   'Junín 501, S2000 Rosario, Santa Fe, Argentina',
#   'Av. Pellegrini 2202, S2000QDN Rosario, Santa Fe, Argentina',
#   'Rioja 411, S2000AYA Rosario, Santa Fe, Argentina',
#   'Jujuy 2581, S2000 Rosario, Santa Fe, Argentina'],
#  'rows': [{'elements': [{'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'duration_in_traffic': {'text': '1 min', 'value': 0},
#      'status': 'OK'},
#     {'distance': {'text': '4.1 km', 'value': 4111},
#      'duration': {'text': '13 mins', 'value': 797},
#      'duration_in_traffic': {'text': '12 mins', 'value': 692},
#      'status': 'OK'},
#     {'distance': {'text': '2.9 km', 'value': 2904},
#      'duration': {'text': '9 mins', 'value': 566},
#      'duration_in_traffic': {'text': '8 mins', 'value': 455},
#      'status': 'OK'},
#     {'distance': {'text': '3.5 km', 'value': 3452},
#      'duration': {'text': '10 mins', 'value': 616},
#      'duration_in_traffic': {'text': '8 mins', 'value': 468},
#      'status': 'OK'},
#     {'distance': {'text': '5.0 km', 'value': 5028},
#      'duration': {'text': '15 mins', 'value': 927},
#      'duration_in_traffic': {'text': '14 mins', 'value': 825},
#      'status': 'OK'},
#     {'distance': {'text': '2.4 km', 'value': 2394},
#      'duration': {'text': '7 mins', 'value': 418},
#      'duration_in_traffic': {'text': '6 mins', 'value': 364},
#      'status': 'OK'}]},
#   {'elements': [{'distance': {'text': '3.2 km', 'value': 3153},
#      'duration': {'text': '9 mins', 'value': 561},
#      'duration_in_traffic': {'text': '8 mins', 'value': 476},
#      'status': 'OK'},
#     {'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'duration_in_traffic': {'text': '1 min', 'value': 27},
#      'status': 'OK'},
#     {'distance': {'text': '4.8 km', 'value': 4841},
#      'duration': {'text': '15 mins', 'value': 917},
#      'duration_in_traffic': {'text': '14 mins', 'value': 834},
#      'status': 'OK'},
#     {'distance': {'text': '2.9 km', 'value': 2880},
#      'duration': {'text': '10 mins', 'value': 594},
#      'duration_in_traffic': {'text': '8 mins', 'value': 488},
#      'status': 'OK'},
#     {'distance': {'text': '2.5 km', 'value': 2456},
#      'duration': {'text': '8 mins', 'value': 502},
#      'duration_in_traffic': {'text': '7 mins', 'value': 408},
#      'status': 'OK'},
#     {'distance': {'text': '2.7 km', 'value': 2691},
#      'duration': {'text': '9 mins', 'value': 535},
#      'duration_in_traffic': {'text': '7 mins', 'value': 422},
#      'status': 'OK'}]},
#   {'elements': [{'distance': {'text': '2.4 km', 'value': 2360},
#      'duration': {'text': '9 mins', 'value': 526},
#      'duration_in_traffic': {'text': '9 mins', 'value': 539},
#      'status': 'OK'},
#     {'distance': {'text': '4.5 km', 'value': 4541},
#      'duration': {'text': '15 mins', 'value': 882},
#      'duration_in_traffic': {'text': '13 mins', 'value': 790},
#      'status': 'OK'},
#     {'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'duration_in_traffic': {'text': '1 min', 'value': 0},
#      'status': 'OK'},
#     {'distance': {'text': '4.7 km', 'value': 4676},
#      'duration': {'text': '14 mins', 'value': 859},
#      'duration_in_traffic': {'text': '13 mins', 'value': 785},
#      'status': 'OK'},
#     {'distance': {'text': '5.2 km', 'value': 5217},
#      'duration': {'text': '15 mins', 'value': 876},
#      'duration_in_traffic': {'text': '14 mins', 'value': 843},
#      'status': 'OK'},
#     {'distance': {'text': '2.6 km', 'value': 2591},
#      'duration': {'text': '8 mins', 'value': 491},
#      'duration_in_traffic': {'text': '7 mins', 'value': 442},
#      'status': 'OK'}]},
#   {'elements': [{'distance': {'text': '3.0 km', 'value': 3038},
#      'duration': {'text': '8 mins', 'value': 507},
#      'duration_in_traffic': {'text': '7 mins', 'value': 420},
#      'status': 'OK'},
#     {'distance': {'text': '3.4 km', 'value': 3410},
#      'duration': {'text': '12 mins', 'value': 743},
#      'duration_in_traffic': {'text': '10 mins', 'value': 593},
#      'status': 'OK'},
#     {'distance': {'text': '4.6 km', 'value': 4633},
#      'duration': {'text': '14 mins', 'value': 867},
#      'duration_in_traffic': {'text': '13 mins', 'value': 768},
#      'status': 'OK'},
#     {'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'duration_in_traffic': {'text': '1 min', 'value': 13},
#      'status': 'OK'},
#     {'distance': {'text': '3.8 km', 'value': 3812},
#      'duration': {'text': '14 mins', 'value': 815},
#      'duration_in_traffic': {'text': '11 mins', 'value': 664},
#      'status': 'OK'},
#     {'distance': {'text': '2.5 km', 'value': 2457},
#      'duration': {'text': '8 mins', 'value': 487},
#      'duration_in_traffic': {'text': '7 mins', 'value': 412},
#      'status': 'OK'}]},
#   {'elements': [{'distance': {'text': '4.8 km', 'value': 4845},
#      'duration': {'text': '15 mins', 'value': 925},
#      'duration_in_traffic': {'text': '13 mins', 'value': 758},
#      'status': 'OK'},
#     {'distance': {'text': '1.7 km', 'value': 1692},
#      'duration': {'text': '6 mins', 'value': 365},
#      'duration_in_traffic': {'text': '5 mins', 'value': 286},
#      'status': 'OK'},
#     {'distance': {'text': '6.1 km', 'value': 6110},
#      'duration': {'text': '17 mins', 'value': 1019},
#      'duration_in_traffic': {'text': '16 mins', 'value': 973},
#      'status': 'OK'},
#     {'distance': {'text': '3.5 km', 'value': 3479},
#      'duration': {'text': '11 mins', 'value': 637},
#      'duration_in_traffic': {'text': '9 mins', 'value': 564},
#      'status': 'OK'},
#     {'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'duration_in_traffic': {'text': '1 min', 'value': 12},
#      'status': 'OK'},
#     {'distance': {'text': '4.5 km', 'value': 4462},
#      'duration': {'text': '16 mins', 'value': 936},
#      'duration_in_traffic': {'text': '12 mins', 'value': 709},
#      'status': 'OK'}]},
#   {'elements': [{'distance': {'text': '2.0 km', 'value': 2001},
#      'duration': {'text': '6 mins', 'value': 374},
#      'duration_in_traffic': {'text': '5 mins', 'value': 312},
#      'status': 'OK'},
#     {'distance': {'text': '2.8 km', 'value': 2767},
#      'duration': {'text': '9 mins', 'value': 565},
#      'duration_in_traffic': {'text': '8 mins', 'value': 485},
#      'status': 'OK'},
#     {'distance': {'text': '2.1 km', 'value': 2100},
#      'duration': {'text': '8 mins', 'value': 471},
#      'duration_in_traffic': {'text': '7 mins', 'value': 425},
#      'status': 'OK'},
#     {'distance': {'text': '2.6 km', 'value': 2649},
#      'duration': {'text': '9 mins', 'value': 531},
#      'duration_in_traffic': {'text': '8 mins', 'value': 461},
#      'status': 'OK'},
#     {'distance': {'text': '3.5 km', 'value': 3537},
#      'duration': {'text': '10 mins', 'value': 626},
#      'duration_in_traffic': {'text': '9 mins', 'value': 564},
#      'status': 'OK'},
#     {'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'duration_in_traffic': {'text': '1 min', 'value': 17},
#      'status': 'OK'}]}],
#  'status': 'OK'}

# %%
# Estructurar la Matriz de Distancias en un DataFrame
distancias_data = []
for fila in matriz_res['rows']:
    distancias_data.append([elemento['distance']['text'] for elemento in fila['elements']])

df_matriz = pd.DataFrame(distancias_data, index=nombres_solo, columns=nombres_solo)

# Mostrar Información de Horarios y la Matriz
print("--- HORARIOS DE APERTURA ---")
for lugar in datos_lugares:
    print(f"{lugar['nombre']}:")
    # Imprimimos solo el horario de hoy para no saturar la consola
    print(f"  {lugar['horarios']}\n")
# Out:
# --- HORARIOS DE APERTURA ---
# Rosario:
#   ['Monday: Open 24 hours', 'Tuesday: Open 24 hours', 'Wednesday: Open 24 hours', 'Thursday: Open 24 hours', 'Friday: Open 24 hours', 'Saturday: Open 24 hours', 'Sunday: Open 24 hours']
#
# El Cairo:
#   ['Monday: 8:00\u202fAM\u2009–\u200911:00\u202fPM', 'Tuesday: 8:00\u202fAM\u2009–\u200911:00\u202fPM', 'Wednesday: 8:00\u202fAM\u2009–\u200911:00\u202fPM', 'Thursday: 8:00\u202fAM\u2009–\u200911:00\u202fPM', 'Friday: 8:00\u202fAM\u2009–\u200911:00\u202fPM', 'Saturday: 8:00\u202fAM\u2009–\u200911:00\u202fPM', 'Sunday: 4:00\u2009–\u200911:00\u202fPM']
#
# Alto Rosario Shopping:
#   ['Monday: 10:00\u202fAM\u2009–\u200912:00\u202fAM', 'Tuesday: 10:00\u202fAM\u2009–\u200912:00\u202fAM', 'Wednesday: 10:00\u202fAM\u2009–\u200912:00\u202fAM', 'Thursday: 10:00\u202fAM\u2009–\u200912:00\u202fAM', 'Friday: 10:00\u202fAM\u2009–\u20091:00\u202fAM', 'Saturday: 10:00\u202fAM\u2009–\u20091:00\u202fAM', 'Sunday: 10:00\u202fAM\u2009–\u200912:00\u202fAM']
#
# Museo Municipal de Bellas Artes Juan B. Castagnino:
#   ['Monday: Closed', 'Tuesday: Closed', 'Wednesday: 2:00\u2009–\u20098:00\u202fPM', 'Thursday: 2:00\u2009–\u20098:00\u202fPM', 'Friday: 2:00\u2009–\u20098:00\u202fPM', 'Saturday: 11:00\u202fAM\u2009–\u20098:00\u202fPM', 'Sunday: 11:00\u202fAM\u2009–\u20098:00\u202fPM']
#
# VIP Rosario:
#   ['Monday: 8:00\u202fAM\u2009–\u200912:00\u202fAM', 'Tuesday: 8:00\u202fAM\u2009–\u200912:00\u202fAM', 'Wednesday: 8:00\u202fAM\u2009–\u200912:00\u202fAM', 'Thursday: 8:00\u202fAM\u2009–\u200912:00\u202fAM', 'Friday: 8:00\u202fAM\u2009–\u20091:00\u202fAM', 'Saturday: 8:30\u202fAM\u2009–\u20091:00\u202fAM', 'Sunday: 8:00\u202fAM\u2009–\u200912:00\u202fAM']
#
# Ruffo Coffee Co.:
#   ['Monday: 7:30\u202fAM\u2009–\u20098:30\u202fPM', 'Tuesday: 7:30\u202fAM\u2009–\u20098:30\u202fPM', 'Wednesday: 7:30\u202fAM\u2009–\u20098:30\u202fPM', 'Thursday: 7:30\u202fAM\u2009–\u20098:30\u202fPM', 'Friday: 7:30\u202fAM\u2009–\u20098:30\u202fPM', 'Saturday: 8:30\u202fAM\u2009–\u20098:30\u202fPM', 'Sunday: 8:30\u202fAM\u2009–\u20098:30\u202fPM']

# %%
distancias_data
# Out:
# [['1 m', '4.1 km', '2.9 km', '3.5 km', '5.0 km', '2.4 km'],
#  ['3.2 km', '1 m', '4.8 km', '2.9 km', '2.5 km', '2.7 km'],
#  ['2.4 km', '4.5 km', '1 m', '4.7 km', '5.2 km', '2.6 km'],
#  ['3.0 km', '3.4 km', '4.6 km', '1 m', '3.8 km', '2.5 km'],
#  ['4.8 km', '1.7 km', '6.1 km', '3.5 km', '1 m', '4.5 km'],
#  ['2.0 km', '2.8 km', '2.1 km', '2.6 km', '3.5 km', '1 m']]
